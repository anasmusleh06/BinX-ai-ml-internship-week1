# %% [markdown]
# #  Environment Setup & the Jupyter Workflow

# %% [markdown]
# #### Week 1 - Day 1

# %% [markdown]
# This notebook covers 4 basic Python exercises:
#
# 1. Creating and activate a **virtual environment**, then install **numpy**, **pandas**, **matplotlib**, and **jupyter**.
# 2. Launching Jupyter and **create a notebook** mixing at least one **Markdown cell** and one **code cell**.
# 3. Runing a code cell that prints the **installed version of each library** to confirm the setup.
# 4. **Freezing the environment** to requirements.txt.
# 5. Initializing a **Git repository**, **commit** the notebook and requirements.txt, and **push** to GitHub.
# > Note: Words written in bold represents key topics that were studied and covered during the day.

# %% [markdown]
# > **This Cell checks for copies of installed libraries.**

# %%
import numpy as np
import pandas as pd
import matplotlib

print("NumPy version:", np.__version__)              # print the version of each library (NumPy, Pandas and Matplotlib) to confirm the setup.
print("Pandas version:", pd.__version__)
print("Matplotlib version:", matplotlib.__version__)

import sys
print("Python version:", sys.version)
# Out:
# NumPy version: 2.5.1
# Pandas version: 3.0.3
# Matplotlib version: 3.11.1
# Python version: 3.14.3 (tags/v3.14.3:323c59a, Feb  3 2026, 16:04:56) [MSC v.1944 64 bit (AMD64)]

# %% [markdown]
# **Note: The above exercise are explained by Markdown cell and the solution is explained by comments.**
